# %%
import os
import pydicom
import cv2
import glob
import multiprocessing as mp
import numpy as np
from tqdm import tqdm

# %%
dir_dcm = './stage2/stage_2_train_images/'
dir_img = './stage2/train512/'

# %%
# Functions

def window_image(img, window_center, window_width, intercept, slope):
    """
    https://www.kaggle.com/omission/eda-view-dicom-images-with-correct-windowing
    """
    img = (img * slope + intercept)
    img_min = window_center - window_width // 2
    img_max = window_center + window_width // 2
    img[img < img_min] = img_min
    img[img > img_max] = img_max

    return img


def get_first_of_dicom_field_as_int(x):
    """
    https://www.kaggle.com/omission/eda-view-dicom-images-with-correct-windowing
    """
    # get x[0] as in int is x is a 'pydicom.multival.MultiValue', otherwise get int(x)
    if type(x) == pydicom.multival.MultiValue:
        return int(x[0])
    else:
        return int(x)


def get_windowing(data):
    """
    https://www.kaggle.com/omission/eda-view-dicom-images-with-correct-windowing
    """
    dicom_fields = [data[('0028', '1050')].value,  # window center
                    data[('0028', '1051')].value,  # window width
                    data[('0028', '1052')].value,  # intercept
                    data[('0028', '1053')].value]  # slope
    return [get_first_of_dicom_field_as_int(x) for x in dicom_fields]

def convert_to_png(dcm_in):

    dcm = pydicom.dcmread(dcm_in)
    window_center, window_width, intercept, slope = get_windowing(dcm)

    img = pydicom.read_file(dcm_in).pixel_array
    img = window_image(img, window_center, window_width, intercept, slope)
    cv2.imwrite(os.path.join(dir_img, os.path.basename(dcm_in)[:-3] + 'png'), img)

# %%
dicom_files = []
for dicom in os.listdir(dir_dcm):
    dicom_files.append('./stage2/stage_2_train_images/' + dicom)

# %%
# Extract images in parallel

#dicom = glob.glob(os.path.join(dir_dcm, '*.dcm'))

pool = mp.Pool(mp.cpu_count())
pool.map(convert_to_png, dicom_files)
pool.close()
# Out:
# Process ForkPoolWorker-85:
# Process ForkPoolWorker-74:
# Process ForkPoolWorker-88:
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-71:
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-79:
# Process ForkPoolWorker-90:
# Process ForkPoolWorker-69:
# Process ForkPoolWorker-91:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-77:
# Process ForkPoolWorker-83:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e1a79ff86441> in <module>
#       3 #dicom = glob.glob(os.path.join(dir_dcm, '*.dcm'))
#       4
# ----> 5 pool = mp.Pool(mp.cpu_count())
#       6 pool.map(convert_to_png, dicom_files)
#       7 pool.close()
#
# ~/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117         from .pool import Pool
#     118         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 119                     context=self.get_context())
#     120
#     121     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     188             target=Pool._handle_tasks,
#     189             args=(self._taskqueue, self._quick_put, self._outqueue,
# --> 190                   self._pool, self._cache)
#     191             )
#     192         self._task_handler.daemon = True
#
# ~/anaconda3/envs/kaggle/lib/python3.7/threading.py in __init__(self, group, target, name, args, kwargs, daemon)
#     797         self._ident = None
#     798         self._tstate_lock = None
# --> 799         self._started = Event()
#     800         self._is_stopped = False
#     801         self._initialized = True
#
# ~/anaconda3/envs/kaggle/lib/python3.7/threading.py in __init__(self)
#     497     # After Tim Peters' event class (without is_posted())
#     498
# --> 499     def __init__(self):
#     500         self._cond = Condition(Lock())
#     501         self._flag = False
#
# KeyboardInterrupt:
# Process ForkPoolWorker-93:
# Process ForkPoolWorker-73:
# Process ForkPoolWorker-81:
# Process ForkPoolWorker-86:
# Process ForkPoolWorker-89:
# Process ForkPoolWorker-82:
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-92:
# Process ForkPoolWorker-75:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-68:
# Process ForkPoolWorker-66:
# Process ForkPoolWorker-78:
# Process ForkPoolWorker-72:
# Process ForkPoolWorker-84:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home
lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-95:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/pool.py", line 101, in worker
#     inqueue._writer.close()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Process ForkPoolWorker-94:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/connection.py", line 177, in close
#     self._close()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/connection.py", line 360, in _close
#     def _close(self, _close=os.close):
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/pengbo/anaconda3/envs/kaggle/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
